# %%
## starting fresh after some hiccups

# %%
import censusdata
import pandas as pd 
import numpy as np

# %% [markdown]
# ## ASSEMBLE DATASET USING censusdata LIBRARY

# %%
## assembly of test tables 
## block1 are general demographics like population size and age 

block1_dems = censusdata.download('acs5', 2014,
           censusdata.censusgeo([('state', '27'),
                                 ('county', '*'),]),
                                  ['B01003_001E','B01001_002E', 'B01001_026E', ## total pop, male & female
                                   'B01001_003E','B01001_004E','B01001_005E',
                                  'B01001_006E','B01001_007E','B01001_008E',
                                  'B01001_009E','B01001_010E','B01001_011E',
                                   'B01001_012E','B01001_013E','B01001_014E',
                                   'B01001_015E','B01001_016E','B01001_017E',
                                   'B01001_018E','B01001_019E','B01001_020E',
                                   'B01001_021E','B01001_022E','B01001_023E',
                                   'B01001_024E','B01001_025E','B01001_027E',
                                   'B01001_028E','B01001_029E','B01001_030E',
                                   'B01001_031E','B01001_032E','B01001_033E',
                                   'B01001_034E','B01001_035E','B01001_036E',
                                   'B01001_037E','B01001_038E','B01001_039E',
                                   'B01001_040E','B01001_041E','B01001_042E',
                                   'B01001_043E','B01001_044E','B01001_045E',
                                   'B01001_046E','B01001_047E','B01001_048E',
                                   'B01001_049E', ## Sex by Age, 46 variants, ages grouped 
                                   'B01002_001E','B01002_002E','B01002_003E'] ) # Median ages. total & by sex

# %%
## rename columns for population totals and totals by sex 

block1_dems.rename(columns = {'B01003_001E':"total_pop",
                             'B01001_002E':"total_pop_male", 
                             'B01001_026E':"total_pop_female"},inplace=True)

# %%
## rename final columns for median ages and median ages by sex 

block1_dems.rename(columns = {'B01002_001E':"median_age_all",
                   'B01002_002E':"median_age_male",
                   'B01002_003E':"median_age_female"}, inplace=True)

# %%
## create age bands that are not separated by gender 
## this is the fixed version 

block1_dems["0-17years"] = (block1_dems.B01001_003E + block1_dems.B01001_004E + block1_dems.B01001_005E + 
                            block1_dems.B01001_006E + block1_dems.B01001_027E + block1_dems.B01001_028E + 
                            block1_dems.B01001_029E + block1_dems.B01001_030E)

block1_dems["18-24years"] = (block1_dems.B01001_007E + block1_dems.B01001_008E + block1_dems.B01001_009E + 
                            block1_dems.B01001_010E + block1_dems.B01001_031E + block1_dems.B01001_032E + 
                            block1_dems.B01001_033E + block1_dems.B01001_034E)

block1_dems["25-44years"] = (block1_dems.B01001_011E + block1_dems.B01001_012E + block1_dems.B01001_013E + 
                            block1_dems.B01001_014E + block1_dems.B01001_035E + block1_dems.B01001_036E + 
                            block1_dems.B01001_037E + block1_dems.B01001_038E)

block1_dems["45-64years"] = (block1_dems.B01001_015E + block1_dems.B01001_016E + block1_dems.B01001_017E + 
                            block1_dems.B01001_018E + block1_dems.B01001_019E + block1_dems.B01001_039E + 
                            block1_dems.B01001_040E + block1_dems.B01001_041E + block1_dems.B01001_042E + 
                            block1_dems.B01001_043E)

block1_dems["65+years"] = (block1_dems.B01001_020E + block1_dems.B01001_021E + block1_dems.B01001_022E + 
                            block1_dems.B01001_023E + block1_dems.B01001_024E + block1_dems.B01001_025E + 
                            block1_dems.B01001_044E + block1_dems.B01001_045E + block1_dems.B01001_046E + 
                          block1_dems.B01001_047E + block1_dems.B01001_048E + block1_dems.B01001_049E)

# %%
block1_dems.drop(['B01001_003E','B01001_004E','B01001_005E',
                 'B01001_006E','B01001_007E','B01001_008E'],axis=1,inplace=True)
block1_dems.drop(['B01001_009E','B01001_010E','B01001_011E',
                 'B01001_012E','B01001_013E','B01001_014E'],axis=1,inplace=True)
block1_dems.drop(['B01001_015E','B01001_016E','B01001_017E',
                 'B01001_018E','B01001_019E','B01001_020E'],axis=1,inplace=True)
block1_dems.drop(['B01001_021E','B01001_022E','B01001_023E',
                 'B01001_024E','B01001_025E','B01001_027E'],axis=1,inplace=True)
block1_dems.drop(['B01001_028E','B01001_029E','B01001_030E',
                 'B01001_031E','B01001_032E','B01001_033E'],axis=1,inplace=True)
block1_dems.drop(['B01001_034E','B01001_035E','B01001_036E',
                 'B01001_037E','B01001_038E','B01001_039E'],axis=1,inplace=True)
block1_dems.drop(['B01001_040E','B01001_041E','B01001_042E',
                 'B01001_043E','B01001_044E','B01001_045E'],axis=1,inplace=True)
block1_dems.drop(['B01001_046E','B01001_047E','B01001_048E',
                 'B01001_049E'],axis=1,inplace=True)

# %%
block1_dems["county_index"] = ["Aitkin County","Anoka County","Becker County",
                               "Beltrami County","Benton County","Big Stone County",
                               "Blue Earth County","Brown County","Carlton County",
                               "Carver County","Cass County","Chippewa County",
                               "Chisago County","Clay County","Clearwater County",
                               "Cook County","Cottonwood County","Crow Wing County",
                               "Dakota County","Dodge County","Douglas County",
                               "Faribault County","Fillmore County","Freeborn County",
                               "Goodhue County","Grant County","Hennepin County",
                               "Houston County","Hubbard County","Isanti County",
                               "Itasca County","Jackson County","Kanabec County",
                               "Kandiyohi County","Kittson County","Koochiching County",
                               "Lac qui Parle County","Lake County","Lake of the Woods County",
                               "Le Sueur County","Lincoln County","Lyon County",
                               "McLeod County","Mahnomen County","Marshall County",
                               "Martin County","Meeker County","Mille Lacs County",
                               "Morrison County","Mower County","Murray County",
                               "Nicollet County","Nobles County","Norman County",
                               "Olmsted County","Otter Tail County","Pennington County",
                               "Pine County","Pipestone County","Polk County",
                               "Pope County","Ramsey County","Red Lake County",
                               "Redwood County","Renville County","Rice County",
                               "Rock County","Roseau County","St. Louis County",
                               "Scott County","Sherburne County","Sibley County",
                               "Stearns County","Steele County","Stevens County",
                               "Swift County","Todd County","Traverse County",
                               "Wabasha County","Wadena County","Waseca County",
                               "Washington County","Watonwan County","Wilkin County",
                               "Winona County","Wright County","Yellow Medicine County"]

block1_dems.set_index("county_index",inplace=True)

# %%
block1_dems.head(3)
# Out:
#                total_pop  total_pop_male  total_pop_female  median_age_all  \
# county_index
# Aitkin County      15964            8103              7861            52.6
# Anoka County      336316          168202            168114            37.6
# Becker County      32971           16556             16415            42.6
#
#                median_age_male  median_age_female  0-17years  18-24years  \
# county_index
# Aitkin County             52.3               52.9       2804         817
# Anoka County              36.8               38.4      84366       27322
# Becker County             42.0               43.3       8118        2236
#
#                25-44years  45-64years  65+years
# county_index
# Aitkin County        2609        5144      4590
# Anoka County        91238       97056     36334
# Becker County        7051        9532      6034

# %%
## Education Table

# %%
block2_edem = censusdata.download('acs5', 2014, 
           censusdata.censusgeo([('state', '27'),
                                 ('county', '*'),]),
                                  ['B15003_002E','B15003_003E', 'B15003_004E',
                                  'B15003_005E','B15003_006E', 'B15003_007E',
                                  'B15003_008E','B15003_009E', 'B15003_010E',
                                  'B15003_011E','B15003_012E', 'B15003_013E',
                                  'B15003_014E','B15003_015E', 'B15003_016E',
                                  'B15003_017E','B15003_018E', 'B15003_019E',
                                  'B15003_020E','B15003_021E', 'B15003_022E',
                                  'B15003_023E','B15003_024E', 'B15003_025E', ## Educational Attainment For The Population 25 Years And Over
                                   'B23025_004E','B23025_005E','B23025_007E', 
                                  'B23025_001E']) ## Employment for 16 and older

# %%
## now bin the attainment levels into 3 groups 

block2_edem["Grade_School"] = (block2_edem.B15003_002E + block2_edem.B15003_003E + 
                           block2_edem.B15003_004E + block2_edem.B15003_005E + 
                           block2_edem.B15003_006E + block2_edem.B15003_007E + 
                           block2_edem.B15003_008E + block2_edem.B15003_009E + 
                           block2_edem.B15003_010E + block2_edem.B15003_011E + 
                           block2_edem.B15003_012E + block2_edem.B15003_013E + 
                           block2_edem.B15003_014E + block2_edem.B15003_015E + 
                           block2_edem.B15003_016E )

block2_edem["HS_Diploma_GED"] = (block2_edem.B15003_017E + block2_edem.B15003_018E ) 

block2_edem["Higher_Ed"] = (block2_edem.B15003_019E + block2_edem.B15003_020E + 
                           block2_edem.B15003_021E + block2_edem.B15003_022E + 
                           block2_edem.B15003_023E + block2_edem.B15003_024E + 
                           block2_edem.B15003_025E )

# %%
## drop the columns used to make the education bands 

block2_edem.drop(['B15003_002E','B15003_003E', 'B15003_004E',
                  'B15003_005E','B15003_006E', 'B15003_007E'],axis=1,inplace=True)

block2_edem.drop(['B15003_008E','B15003_009E', 'B15003_010E',
                  'B15003_011E','B15003_012E', 'B15003_013E'],axis=1,inplace=True)

block2_edem.drop(['B15003_014E','B15003_015E', 'B15003_016E',
                  'B15003_017E','B15003_018E', 'B15003_019E'],axis=1,inplace=True)

block2_edem.drop(['B15003_020E','B15003_021E', 'B15003_022E',
                  'B15003_023E','B15003_024E', 'B15003_025E'],axis=1,inplace=True)

# %%
## rename the employment columns 

block2_edem.rename(columns = {'B23025_004E':"Employed",'B23025_005E':"Unemployed",
                              'B23025_007E':"Not_in_Labor_Force",'B23025_001E':"Total_16&Over"},
                  inplace=True)

# %%
block2_edem["county_index"] = ["Aitkin County","Anoka County","Becker County",
                               "Beltrami County","Benton County","Big Stone County",
                               "Blue Earth County","Brown County","Carlton County",
                               "Carver County","Cass County","Chippewa County",
                               "Chisago County","Clay County","Clearwater County",
                               "Cook County","Cottonwood County","Crow Wing County",
                               "Dakota County","Dodge County","Douglas County",
                               "Faribault County","Fillmore County","Freeborn County",
                               "Goodhue County","Grant County","Hennepin County",
                               "Houston County","Hubbard County","Isanti County",
                               "Itasca County","Jackson County","Kanabec County",
                               "Kandiyohi County","Kittson County","Koochiching County",
                               "Lac qui Parle County","Lake County","Lake of the Woods County",
                               "Le Sueur County","Lincoln County","Lyon County",
                               "McLeod County","Mahnomen County","Marshall County",
                               "Martin County","Meeker County","Mille Lacs County",
                               "Morrison County","Mower County","Murray County",
                               "Nicollet County","Nobles County","Norman County",
                               "Olmsted County","Otter Tail County","Pennington County",
                               "Pine County","Pipestone County","Polk County",
                               "Pope County","Ramsey County","Red Lake County",
                               "Redwood County","Renville County","Rice County",
                               "Rock County","Roseau County","St. Louis County",
                               "Scott County","Sherburne County","Sibley County",
                               "Stearns County","Steele County","Stevens County",
                               "Swift County","Todd County","Traverse County",
                               "Wabasha County","Wadena County","Waseca County",
                               "Washington County","Watonwan County","Wilkin County",
                               "Winona County","Wright County","Yellow Medicine County"]

block2_edem.set_index("county_index",inplace=True)

# %%
block2_edem.head()
# Out:
#                  Employed  Unemployed  Not_in_Labor_Force  Total_16&Over  \
# county_index
# Aitkin County        6531         576                6396          13510
# Anoka County       178642       13803               69522         262119
# Becker County       15668         742                9377          25793
# Beltrami County     20340        2521               12263          35131
# Benton County       19701        1735                8821          30263
#
#                  Grade_School  HS_Diploma_GED  Higher_Ed
# county_index
# Aitkin County            1181            5034       6128
# Anoka County            14860           64700     145068
# Becker County            2151            7483      12983
# Beltrami County          2710            7347      17211
# Benton County            2170            8474      15132

# %%
## block 3 will show INcome data and data about households receiving BEnefits 

block3_inbe = censusdata.download('acs5', 2014,
           censusdata.censusgeo([('state', '27'),
                                 ('county', '*'),]),
                                  ['B19326_001E','B19326_003E', 'B19326_004E',
                                   'B19326_006E','B19326_007E', ## median income for full and part time workers (15yrs+)
                                   'B22003_001E','B22003_002E','B22003_005E']) ## households receiving benefits

# %%
## combine and rename INCOME and BENEFITS related columns 

block3_inbe["med_income_FT"] = ((block3_inbe.B19326_003E + block3_inbe.B19326_006E) / 2) ## male and female full-time
block3_inbe["med_income_PT"] = ((block3_inbe.B19326_004E + block3_inbe.B19326_007E) / 2) ## male and female part-time 

block3_inbe.rename(columns = {'B19326_001E':"total_median_income",
                              'B22003_001E':"total_households",
                   'B22003_002E':"households_receiving_benefits",
                   'B22003_005E':"households_not_receiving_benefits"},inplace=True)

# %%
## remove obsolete columns 

block3_inbe.drop(['B19326_003E','B19326_004E','B19326_006E','B19326_007E'],axis=1,inplace=True)

# %%
block3_inbe["county_index"] = ["Aitkin County","Anoka County","Becker County",
                               "Beltrami County","Benton County","Big Stone County",
                               "Blue Earth County","Brown County","Carlton County",
                               "Carver County","Cass County","Chippewa County",
                               "Chisago County","Clay County","Clearwater County",
                               "Cook County","Cottonwood County","Crow Wing County",
                               "Dakota County","Dodge County","Douglas County",
                               "Faribault County","Fillmore County","Freeborn County",
                               "Goodhue County","Grant County","Hennepin County",
                               "Houston County","Hubbard County","Isanti County",
                               "Itasca County","Jackson County","Kanabec County",
                               "Kandiyohi County","Kittson County","Koochiching County",
                               "Lac qui Parle County","Lake County","Lake of the Woods County",
                               "Le Sueur County","Lincoln County","Lyon County",
                               "McLeod County","Mahnomen County","Marshall County",
                               "Martin County","Meeker County","Mille Lacs County",
                               "Morrison County","Mower County","Murray County",
                               "Nicollet County","Nobles County","Norman County",
                               "Olmsted County","Otter Tail County","Pennington County",
                               "Pine County","Pipestone County","Polk County",
                               "Pope County","Ramsey County","Red Lake County",
                               "Redwood County","Renville County","Rice County",
                               "Rock County","Roseau County","St. Louis County",
                               "Scott County","Sherburne County","Sibley County",
                               "Stearns County","Steele County","Stevens County",
                               "Swift County","Todd County","Traverse County",
                               "Wabasha County","Wadena County","Waseca County",
                               "Washington County","Watonwan County","Wilkin County",
                               "Winona County","Wright County","Yellow Medicine County"]

block3_inbe.set_index("county_index",inplace=True)

# %%
block3_inbe.head(10)
# Out:
#                    total_median_income  total_households  \
# county_index
# Aitkin County                    22742              7637
# Anoka County                     34771            123446
# Becker County                    25884             13534
# Beltrami County                  21282             16793
# Benton County                    26509             15466
# Big Stone County                 26239              2316
# Blue Earth County                23520             24719
# Brown County                     25767             10749
# Carlton County                   26084             13542
# Carver County                    39519             33813
#
#                    households_receiving_benefits  \
# county_index
# Aitkin County                                781
# Anoka County                                9264
# Becker County                               1538
# Beltrami County                             2508
# Benton County                               1793
# ...

# %%
## INcome and BEnefits table is complete (for now) 
## moving on to the HealthCare COverage table 
## I'm really intimidated by this one

# %%
block4_hcco = censusdata.download('acs5', 2014,
           censusdata.censusgeo([('state', '27'),
                                 ('county', '*'),]),
                                  ['B27001_004E','B27001_005E','B27001_007E','B27001_008E',
                                   'B27001_010E','B27001_011E','B27001_013E','B27001_014E',
                                   'B27001_016E','B27001_017E','B27001_019E','B27001_020E',
                                   'B27001_022E','B27001_023E', 'B27001_025E','B27001_026E',
                                   'B27001_028E','B27001_029E','B27001_032E','B27001_033E',
                                   'B27001_035E','B27001_036E','B27001_038E','B27001_039E',
                                   'B27001_041E','B27001_042E','B27001_044E','B27001_045E',
                                   'B27001_047E','B27001_048E','B27001_050E','B27001_051E',
                                   'B27001_053E','B27001_054E','B27001_056E','B27001_057E',
                                   ## Health Insurance Coverage Status By Sex By Age 
                                  'B27002_004E','B27002_005E','B27002_007E','B27002_008E',
                                   'B27002_010E','B27002_011E','B27002_013E','B27002_014E',
                                   'B27002_016E','B27002_017E','B27002_019E','B27002_020E',
                                   'B27002_022E','B27002_023E', 'B27002_025E','B27002_026E',
                                   'B27002_028E','B27002_029E','B27002_032E','B27002_033E',
                                   'B27002_035E','B27002_036E','B27002_038E','B27002_039E',
                                   'B27002_041E','B27002_042E','B27002_044E','B27002_045E',
                                   'B27002_047E','B27002_048E','B27002_050E','B27002_051E',
                                   'B27002_053E','B27002_054E','B27002_056E','B27002_057E',
                                   ## Private Health Insurance Status By Sex By Age
                                   'B27003_004E','B27003_005E','B27003_007E','B27003_008E',
                                   'B27003_010E','B27003_011E','B27003_013E','B27003_014E',
                                   'B27003_016E','B27003_017E','B27003_019E','B27003_020E',
                                   'B27003_022E','B27003_023E', 'B27003_025E','B27003_026E',
                                   'B27003_028E','B27003_029E','B27003_032E','B27003_033E',
                                   'B27003_035E','B27003_036E','B27003_038E','B27003_039E',
                                   'B27003_041E','B27003_042E','B27003_044E','B27003_045E',
                                   'B27003_047E','B27003_048E','B27003_050E','B27003_051E',
                                   'B27003_053E','B27003_054E','B27003_056E','B27003_057E',]) 
                                   ## Public Health Insurance Status By Sex By Age

# %%
## Health Insurance Coverage Status By Sex By Age B27001
## create age ranged groups for those with and without ANY health coverage  
## w_coverage
## no_coverage 

block4_hcco["0-17years_w_coverage"] = (block4_hcco.B27001_004E + block4_hcco.B27001_007E + 
                                       block4_hcco.B27001_032E + block4_hcco.B27001_035E)
block4_hcco["0-17years_no_coverage"] = (block4_hcco.B27001_005E + block4_hcco.B27001_008E + 
                                        block4_hcco.B27001_033E + block4_hcco.B27001_036E) 

block4_hcco["18-24years_w_coverage"] = (block4_hcco.B27001_010E + block4_hcco.B27001_038E)
block4_hcco["18-24years_no_coverage"] = (block4_hcco.B27001_011E + block4_hcco.B27001_039E)

block4_hcco["25-44years_w_coverage"] = (block4_hcco.B27001_013E + block4_hcco.B27001_016E + 
                                        block4_hcco.B27001_041E + block4_hcco.B27001_044E)
block4_hcco["25-44years_no_coverage"] = (block4_hcco.B27001_014E + block4_hcco.B27001_017E + 
                                         block4_hcco.B27001_042E + block4_hcco.B27001_045E)

block4_hcco["45-64years_w_coverage"] = (block4_hcco.B27001_019E + block4_hcco.B27001_022E + 
                                        block4_hcco.B27001_047E + block4_hcco.B27001_050E)
block4_hcco["45-64years_no_coverage"] = (block4_hcco.B27001_020E + block4_hcco.B27001_023E + 
                                         block4_hcco.B27001_048E + block4_hcco.B27001_051E)

block4_hcco["65+years_w_coverage"] = (block4_hcco.B27001_025E + block4_hcco.B27001_028E + 
                                      block4_hcco.B27001_053E + block4_hcco.B27001_056E)
block4_hcco["65+years_no_coverage"] = (block4_hcco.B27001_026E + block4_hcco.B27001_029E + 
                                       block4_hcco.B27001_054E + block4_hcco.B27001_057E) 

block4_hcco["total_w_coverage"] = (block4_hcco.B27001_004E + block4_hcco.B27001_007E + 
                                   block4_hcco.B27001_032E + block4_hcco.B27001_035E + 
                                   block4_hcco.B27001_010E + block4_hcco.B27001_038E +
                                   block4_hcco.B27001_013E + block4_hcco.B27001_016E + 
                                   block4_hcco.B27001_041E + block4_hcco.B27001_044E + 
                                   block4_hcco.B27001_019E + block4_hcco.B27001_022E + 
                                   block4_hcco.B27001_047E + block4_hcco.B27001_050E + 
                                   block4_hcco.B27001_025E + block4_hcco.B27001_028E + 
                                   block4_hcco.B27001_053E + block4_hcco.B27001_056E) 
                                   
block4_hcco["total_no_coverage"] = (block4_hcco.B27001_005E + block4_hcco.B27001_008E + 
                                    block4_hcco.B27001_033E + block4_hcco.B27001_036E + 
                                    block4_hcco.B27001_011E + block4_hcco.B27001_039E + 
                                    block4_hcco.B27001_014E + block4_hcco.B27001_017E + 
                                    block4_hcco.B27001_042E + block4_hcco.B27001_045E + 
                                    block4_hcco.B27001_020E + block4_hcco.B27001_023E + 
                                    block4_hcco.B27001_048E + block4_hcco.B27001_051E + 
                                    block4_hcco.B27001_026E + block4_hcco.B27001_029E + 
                                    block4_hcco.B27001_054E + block4_hcco.B27001_057E)

# %%
## Private Health Insurance Status By Sex By Age B27002
## create age ranged groups for those with and without PRIVATE health coverage  
## w_pvcoverage 
## no_pv_coverage 

block4_hcco["0-17years_w_pvcoverage"] = (block4_hcco.B27002_004E + block4_hcco.B27002_007E + 
                                       block4_hcco.B27002_032E + block4_hcco.B27002_035E)
block4_hcco["0-17years_no_pvcoverage"] = (block4_hcco.B27002_005E + block4_hcco.B27002_008E + 
                                        block4_hcco.B27002_033E + block4_hcco.B27002_036E) 

block4_hcco["18-24years_w_pvcoverage"] = (block4_hcco.B27002_010E + block4_hcco.B27002_038E)
block4_hcco["18-24years_no_pvcoverage"] = (block4_hcco.B27002_011E + block4_hcco.B27002_039E)

block4_hcco["25-44years_w_pvcoverage"] = (block4_hcco.B27002_013E + block4_hcco.B27002_016E + 
                                        block4_hcco.B27002_041E + block4_hcco.B27002_044E)
block4_hcco["25-44years_no_pvcoverage"] = (block4_hcco.B27002_014E + block4_hcco.B27002_017E + 
                                         block4_hcco.B27002_042E + block4_hcco.B27002_045E)

block4_hcco["45-64years_w_pvcoverage"] = (block4_hcco.B27002_019E + block4_hcco.B27002_022E + 
                                        block4_hcco.B27002_047E + block4_hcco.B27002_050E)
block4_hcco["45-64years_no_pvcoverage"] = (block4_hcco.B27002_020E + block4_hcco.B27002_023E + 
                                         block4_hcco.B27002_048E + block4_hcco.B27002_051E)

block4_hcco["65+years_w_pvcoverage"] = (block4_hcco.B27002_025E + block4_hcco.B27002_028E + 
                                      block4_hcco.B27002_053E + block4_hcco.B27002_056E)
block4_hcco["65+years_no_pvcoverage"] = (block4_hcco.B27002_026E + block4_hcco.B27002_029E + 
                                       block4_hcco.B27002_054E + block4_hcco.B27002_057E)

block4_hcco["total_w_pvcoverage"] = (block4_hcco.B27002_004E + block4_hcco.B27002_007E + 
                                   block4_hcco.B27002_032E + block4_hcco.B27002_035E + 
                                   block4_hcco.B27002_010E + block4_hcco.B27002_038E +
                                   block4_hcco.B27002_013E + block4_hcco.B27002_016E + 
                                   block4_hcco.B27002_041E + block4_hcco.B27002_044E + 
                                   block4_hcco.B27002_019E + block4_hcco.B27002_022E + 
                                   block4_hcco.B27002_047E + block4_hcco.B27002_050E + 
                                   block4_hcco.B27002_025E + block4_hcco.B27002_028E + 
                                   block4_hcco.B27002_053E + block4_hcco.B27002_056E) 
                                   
block4_hcco["total_no_pvcoverage"] = (block4_hcco.B27002_005E + block4_hcco.B27002_008E + 
                                    block4_hcco.B27002_033E + block4_hcco.B27002_036E + 
                                    block4_hcco.B27002_011E + block4_hcco.B27002_039E + 
                                    block4_hcco.B27002_014E + block4_hcco.B27002_017E + 
                                    block4_hcco.B27002_042E + block4_hcco.B27002_045E + 
                                    block4_hcco.B27002_020E + block4_hcco.B27002_023E + 
                                    block4_hcco.B27002_048E + block4_hcco.B27002_051E + 
                                    block4_hcco.B27002_026E + block4_hcco.B27002_029E + 
                                    block4_hcco.B27002_054E + block4_hcco.B27002_057E)

# %%
## Public Health Insurance Status By Sex By Age B27003
## create age ranged groups for those with and without PUBLIC health coverage  
## w_pbcoverage 
## no_pbcoverage 

block4_hcco["0-17years_w_pbcoverage"] = (block4_hcco.B27003_004E + block4_hcco.B27003_007E + 
                                       block4_hcco.B27003_032E + block4_hcco.B27003_035E)
block4_hcco["0-17years_no_pbcoverage"] = (block4_hcco.B27003_005E + block4_hcco.B27003_008E + 
                                        block4_hcco.B27003_033E + block4_hcco.B27003_036E) 

block4_hcco["18-24years_w_pbcoverage"] = (block4_hcco.B27003_010E + block4_hcco.B27003_038E)
block4_hcco["18-24years_no_pbcoverage"] = (block4_hcco.B27003_011E + block4_hcco.B27003_039E)

block4_hcco["25-44years_w_pbcoverage"] = (block4_hcco.B27003_013E + block4_hcco.B27003_016E + 
                                        block4_hcco.B27003_041E + block4_hcco.B27003_044E)
block4_hcco["25-44years_no_pbcoverage"] = (block4_hcco.B27003_014E + block4_hcco.B27003_017E + 
                                         block4_hcco.B27003_042E + block4_hcco.B27003_045E)

block4_hcco["45-64years_w_pbcoverage"] = (block4_hcco.B27003_019E + block4_hcco.B27003_022E + 
                                        block4_hcco.B27003_047E + block4_hcco.B27003_050E)
block4_hcco["45-64years_no_pbcoverage"] = (block4_hcco.B27003_020E + block4_hcco.B27003_023E + 
                                         block4_hcco.B27003_048E + block4_hcco.B27003_051E)

block4_hcco["65+years_w_pbcoverage"] = (block4_hcco.B27003_025E + block4_hcco.B27003_028E + 
                                      block4_hcco.B27003_053E + block4_hcco.B27003_056E)
block4_hcco["65+years_no_pbcoverage"] = (block4_hcco.B27003_026E + block4_hcco.B27003_029E + 
                                       block4_hcco.B27003_054E + block4_hcco.B27003_057E) 

block4_hcco["total_w_pbcoverage"] = (block4_hcco.B27003_004E + block4_hcco.B27003_007E + 
                                   block4_hcco.B27003_032E + block4_hcco.B27003_035E + 
                                   block4_hcco.B27003_010E + block4_hcco.B27003_038E +
                                   block4_hcco.B27003_013E + block4_hcco.B27003_016E + 
                                   block4_hcco.B27003_041E + block4_hcco.B27003_044E + 
                                   block4_hcco.B27003_019E + block4_hcco.B27003_022E + 
                                   block4_hcco.B27003_047E + block4_hcco.B27003_050E + 
                                   block4_hcco.B27003_025E + block4_hcco.B27003_028E + 
                                   block4_hcco.B27003_053E + block4_hcco.B27003_056E) 
                                   
block4_hcco["total_no_pbcoverage"] = (block4_hcco.B27003_005E + block4_hcco.B27003_008E + 
                                    block4_hcco.B27003_033E + block4_hcco.B27003_036E + 
                                    block4_hcco.B27003_011E + block4_hcco.B27003_039E + 
                                    block4_hcco.B27003_014E + block4_hcco.B27003_017E + 
                                    block4_hcco.B27003_042E + block4_hcco.B27003_045E + 
                                    block4_hcco.B27003_020E + block4_hcco.B27003_023E + 
                                    block4_hcco.B27003_048E + block4_hcco.B27003_051E + 
                                    block4_hcco.B27003_026E + block4_hcco.B27003_029E + 
                                    block4_hcco.B27003_054E + block4_hcco.B27003_057E)

# %%
## Remove obsolete columns from B27001 

block4_hcco.drop(['B27001_004E','B27001_005E','B27001_007E','B27001_008E',
                  'B27001_010E','B27001_011E','B27001_013E','B27001_014E'],axis=1,inplace=True) 
block4_hcco.drop(['B27001_016E','B27001_017E','B27001_019E','B27001_020E',
                  'B27001_022E','B27001_023E', 'B27001_025E','B27001_026E'],axis=1,inplace=True)
block4_hcco.drop(['B27001_028E','B27001_029E','B27001_032E','B27001_033E',
                  'B27001_035E','B27001_036E','B27001_038E','B27001_039E'],axis=1,inplace=True)
block4_hcco.drop(['B27001_041E','B27001_042E','B27001_044E','B27001_045E',
                  'B27001_047E','B27001_048E','B27001_050E','B27001_051E'],axis=1,inplace=True)
block4_hcco.drop(['B27001_053E','B27001_054E','B27001_056E','B27001_057E'],axis=1,inplace=True)

# %%
## Remove obsolete columns from B27002 

block4_hcco.drop(['B27002_004E','B27002_005E','B27002_007E','B27002_008E',
                  'B27002_010E','B27002_011E','B27002_013E','B27002_014E'],axis=1,inplace=True) 
block4_hcco.drop(['B27002_016E','B27002_017E','B27002_019E','B27002_020E',
                  'B27002_022E','B27002_023E', 'B27002_025E','B27002_026E'],axis=1,inplace=True)
block4_hcco.drop(['B27002_028E','B27002_029E','B27002_032E','B27002_033E',
                  'B27002_035E','B27002_036E','B27002_038E','B27002_039E'],axis=1,inplace=True)
block4_hcco.drop(['B27002_041E','B27002_042E','B27002_044E','B27002_045E',
                  'B27002_047E','B27002_048E','B27002_050E','B27002_051E'],axis=1,inplace=True)
block4_hcco.drop(['B27002_053E','B27002_054E','B27002_056E','B27002_057E'],axis=1,inplace=True)

# %%
## Remove obsolete columns from B27003 

block4_hcco.drop(['B27003_004E','B27003_005E','B27003_007E','B27003_008E',
                  'B27003_010E','B27003_011E','B27003_013E','B27003_014E'],axis=1,inplace=True) 
block4_hcco.drop(['B27003_016E','B27003_017E','B27003_019E','B27003_020E',
                  'B27003_022E','B27003_023E', 'B27003_025E','B27003_026E'],axis=1,inplace=True)
block4_hcco.drop(['B27003_028E','B27003_029E','B27003_032E','B27003_033E',
                  'B27003_035E','B27003_036E','B27003_038E','B27003_039E'],axis=1,inplace=True)
block4_hcco.drop(['B27003_041E','B27003_042E','B27003_044E','B27003_045E',
                  'B27003_047E','B27003_048E','B27003_050E','B27003_051E'],axis=1,inplace=True)
block4_hcco.drop(['B27003_053E','B27003_054E','B27003_056E','B27003_057E'],axis=1,inplace=True)

# %%
block4_hcco["county_index"] = ["Aitkin County","Anoka County","Becker County",
                               "Beltrami County","Benton County","Big Stone County",
                               "Blue Earth County","Brown County","Carlton County",
                               "Carver County","Cass County","Chippewa County",
                               "Chisago County","Clay County","Clearwater County",
                               "Cook County","Cottonwood County","Crow Wing County",
                               "Dakota County","Dodge County","Douglas County",
                               "Faribault County","Fillmore County","Freeborn County",
                               "Goodhue County","Grant County","Hennepin County",
                               "Houston County","Hubbard County","Isanti County",
                               "Itasca County","Jackson County","Kanabec County",
                               "Kandiyohi County","Kittson County","Koochiching County",
                               "Lac qui Parle County","Lake County","Lake of the Woods County",
                               "Le Sueur County","Lincoln County","Lyon County",
                               "McLeod County","Mahnomen County","Marshall County",
                               "Martin County","Meeker County","Mille Lacs County",
                               "Morrison County","Mower County","Murray County",
                               "Nicollet County","Nobles County","Norman County",
                               "Olmsted County","Otter Tail County","Pennington County",
                               "Pine County","Pipestone County","Polk County",
                               "Pope County","Ramsey County","Red Lake County",
                               "Redwood County","Renville County","Rice County",
                               "Rock County","Roseau County","St. Louis County",
                               "Scott County","Sherburne County","Sibley County",
                               "Stearns County","Steele County","Stevens County",
                               "Swift County","Todd County","Traverse County",
                               "Wabasha County","Wadena County","Waseca County",
                               "Washington County","Watonwan County","Wilkin County",
                               "Winona County","Wright County","Yellow Medicine County"]

block4_hcco.set_index("county_index",inplace=True)

# %%
block4_hcco.head(10)
# Out:
#                    0-17years_w_coverage  0-17years_no_coverage  \
# county_index
# Aitkin County                      2590                    211
# Anoka County                      79833                   4386
# Becker County                      7085                   1026
# Beltrami County                    9856                   1465
# Benton County                      9158                    475
# Big Stone County                    993                     75
# Blue Earth County                 12326                    318
# Brown County                       5284                    262
# Carlton County                     7825                    448
# Carver County                     26401                    755
#
#                    18-24years_w_coverage  18-24years_no_coverage  \
# county_index
# Aitkin County                        660                     140
# Anoka County                       22992                    4026
# ...

# %%
## creating a table for the variable to be predicted in the final model

# %%
block5_pred =  censusdata.download('acs5', 2019,
           censusdata.censusgeo([('state', '27'),
                                 ('county', '*'),]),
                                  ['B01003_001E', ## total 2019 population by county
                                      
                                    'B27001_004E','B27001_005E','B27001_007E','B27001_008E',
                                   'B27001_010E','B27001_011E','B27001_013E','B27001_014E',
                                   'B27001_016E','B27001_017E','B27001_019E','B27001_020E',
                                   'B27001_022E','B27001_023E', 'B27001_025E','B27001_026E',
                                   'B27001_028E','B27001_029E','B27001_032E','B27001_033E',
                                   'B27001_035E','B27001_036E','B27001_038E','B27001_039E',
                                   'B27001_041E','B27001_042E','B27001_044E','B27001_045E',
                                   'B27001_047E','B27001_048E','B27001_050E','B27001_051E',
                                   'B27001_053E','B27001_054E','B27001_056E','B27001_057E',
                                   ## Health Insurance Coverage Status By Sex By Age 

                                   'B27003_004E','B27003_005E','B27003_007E','B27003_008E',
                                   'B27003_010E','B27003_011E','B27003_013E','B27003_014E',
                                   'B27003_016E','B27003_017E','B27003_019E','B27003_020E',
                                   'B27003_022E','B27003_023E', 'B27003_025E','B27003_026E',
                                   'B27003_028E','B27003_029E','B27003_032E','B27003_033E',
                                   'B27003_035E','B27003_036E','B27003_038E','B27003_039E',
                                   'B27003_041E','B27003_042E','B27003_044E','B27003_045E',
                                   'B27003_047E','B27003_048E','B27003_050E','B27003_051E',
                                   'B27003_053E','B27003_054E','B27003_056E','B27003_057E',]) 
                                   ## Public Health Insurance Status By Sex By Age

# %%
block5_pred.rename(columns = {'B01003_001E':"2019_total_pop"},inplace=True)

# %%
## create columns                
block5_pred["2019_total_no_coverage"] = (block5_pred.B27001_005E + block5_pred.B27001_008E + 
                                    block5_pred.B27001_033E + block5_pred.B27001_036E + 
                                    block5_pred.B27001_011E + block5_pred.B27001_039E + 
                                    block5_pred.B27001_014E + block5_pred.B27001_017E + 
                                    block5_pred.B27001_042E + block5_pred.B27001_045E + 
                                    block5_pred.B27001_020E + block5_pred.B27001_023E + 
                                    block5_pred.B27001_048E + block5_pred.B27001_051E + 
                                    block5_pred.B27001_026E + block5_pred.B27001_029E + 
                                    block5_pred.B27001_054E + block5_pred.B27001_057E)

# %%
## create columns 
block5_pred["2019_total_w_pbcoverage"] = (block5_pred.B27003_004E + block5_pred.B27003_007E + 
                                   block5_pred.B27003_032E + block5_pred.B27003_035E + 
                                   block5_pred.B27003_010E + block5_pred.B27003_038E +
                                   block5_pred.B27003_013E + block5_pred.B27003_016E + 
                                   block5_pred.B27003_041E + block5_pred.B27003_044E + 
                                   block5_pred.B27003_019E + block5_pred.B27003_022E + 
                                   block5_pred.B27003_047E + block5_pred.B27003_050E + 
                                   block5_pred.B27003_025E + block5_pred.B27003_028E + 
                                   block5_pred.B27003_053E + block5_pred.B27003_056E)

# %%
## Remove obsolete columns from B27001 

block5_pred.drop(['B27001_004E','B27001_005E','B27001_007E','B27001_008E',
                  'B27001_010E','B27001_011E','B27001_013E','B27001_014E'],axis=1,inplace=True) 
block5_pred.drop(['B27001_016E','B27001_017E','B27001_019E','B27001_020E',
                  'B27001_022E','B27001_023E', 'B27001_025E','B27001_026E'],axis=1,inplace=True)
block5_pred.drop(['B27001_028E','B27001_029E','B27001_032E','B27001_033E',
                  'B27001_035E','B27001_036E','B27001_038E','B27001_039E'],axis=1,inplace=True)
block5_pred.drop(['B27001_041E','B27001_042E','B27001_044E','B27001_045E',
                  'B27001_047E','B27001_048E','B27001_050E','B27001_051E'],axis=1,inplace=True)
block5_pred.drop(['B27001_053E','B27001_054E','B27001_056E','B27001_057E'],axis=1,inplace=True)

## Remove obsolete columns from B27003 

block5_pred.drop(['B27003_004E','B27003_005E','B27003_007E','B27003_008E',
                  'B27003_010E','B27003_011E','B27003_013E','B27003_014E'],axis=1,inplace=True) 
block5_pred.drop(['B27003_016E','B27003_017E','B27003_019E','B27003_020E',
                  'B27003_022E','B27003_023E', 'B27003_025E','B27003_026E'],axis=1,inplace=True)
block5_pred.drop(['B27003_028E','B27003_029E','B27003_032E','B27003_033E',
                  'B27003_035E','B27003_036E','B27003_038E','B27003_039E'],axis=1,inplace=True)
block5_pred.drop(['B27003_041E','B27003_042E','B27003_044E','B27003_045E',
                  'B27003_047E','B27003_048E','B27003_050E','B27003_051E'],axis=1,inplace=True)
block5_pred.drop(['B27003_053E','B27003_054E','B27003_056E','B27003_057E'],axis=1,inplace=True)

# %%
block5_pred["county_index"] = ["Aitkin County","Anoka County","Becker County",
                               "Beltrami County","Benton County","Big Stone County",
                               "Blue Earth County","Brown County","Carlton County",
                               "Carver County","Cass County","Chippewa County",
                               "Chisago County","Clay County","Clearwater County",
                               "Cook County","Cottonwood County","Crow Wing County",
                               "Dakota County","Dodge County","Douglas County",
                               "Faribault County","Fillmore County","Freeborn County",
                               "Goodhue County","Grant County","Hennepin County",
                               "Houston County","Hubbard County","Isanti County",
                               "Itasca County","Jackson County","Kanabec County",
                               "Kandiyohi County","Kittson County","Koochiching County",
                               "Lac qui Parle County","Lake County","Lake of the Woods County",
                               "Le Sueur County","Lincoln County","Lyon County",
                               "McLeod County","Mahnomen County","Marshall County",
                               "Martin County","Meeker County","Mille Lacs County",
                               "Morrison County","Mower County","Murray County",
                               "Nicollet County","Nobles County","Norman County",
                               "Olmsted County","Otter Tail County","Pennington County",
                               "Pine County","Pipestone County","Polk County",
                               "Pope County","Ramsey County","Red Lake County",
                               "Redwood County","Renville County","Rice County",
                               "Rock County","Roseau County","St. Louis County",
                               "Scott County","Sherburne County","Sibley County",
                               "Stearns County","Steele County","Stevens County",
                               "Swift County","Todd County","Traverse County",
                               "Wabasha County","Wadena County","Waseca County",
                               "Washington County","Watonwan County","Wilkin County",
                               "Winona County","Wright County","Yellow Medicine County"]

block5_pred.set_index("county_index",inplace=True)

# %%
squish1 = pd.concat([block1_dems,block2_edem,block3_inbe,
                     block4_hcco,block5_pred], axis=1, join="outer")

# %%
squish1.head(8)

# %%
## trying to download this dataset as a CSV so that I don't have to run all the above cells every time 
#write dataframe to file
squish1.to_csv("capstone_2014&2019.csv")
